# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# get raw data from GCP bucket
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

import os
import glob
import json
from datetime import datetime

from google.cloud import storage

# %%
# The bucket name for the location of the data is in the .env file
BUCKET_NAME = os.environ['BUCKET_NAME']
JSON_FILE = 'all_json_new.pkl'

# %%
class Preprocesser:
    def __init__(self):
        storage_client = storage.Client()
        temp = tempfile.TemporaryFile()
        storage_client.download_blob_to_file(f"gs://{BUCKET_NAME}/{JSON_FILE}", temp)
        self.df_full = pd.read_pickle(temp, compression=None)
        print(self.df_full.shape)
        self.key_slice()
        print(self.df_full.shape)
    
    def key_slice(self):
        keywords = ['incident command system',
            'emergency operations',
            'joint information center',
            'social distancing',
            'childcare closers',
            'travel advisory',
            'travel warning',
            'isolation',
            'qarentine',
            'mass gathering cancellations',
            'school closures',
            'facility closures',
            'facility closures',
            'evacuation',
            'relocation',
            'restricing travel',
            'travel ban',
            'patient cohort',
            'npi']
        self.df_full = self.df_full[self.df_full['body_text'].str.contains('|'.join(keywords), na=False, regex=True)].reset_index()
    
    def remove_stopwords(self,columns):
        stop = stopwords.words('english')
        for col in columns:
            self.df_full[col] = self.df_full[col].astype(str).apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

    def to_tfidf(self,columns):
        for col in columns:
            tfidfv = TfidfVectorizer()
            self.df_full[col + '_tfidf'] = tfidfv.fit_transform(self.df_full[col])
            
    def remove_punc(self, columns):
        for col in columns:
            self.df_full[col] = self.df_full[col].str.replace('[^\w\s]','')
        
def display_wordcloud(text):
    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color='white').generate(text)
    plt.figure()
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %%
prepr = Preprocesser()
# Out:
# (3851, 8)
# (3851, 9)

# %%
# prepr.df_full

# %%
prepr.remove_stopwords(['abstract'])

# %%
prepr.remove_punc(['abstract'])

# %%
prepr.df_full
# Out:
#                                             author_list  \
# 0     [Shengjie Lai, Isaac I Bogoch, Nick W Ruktanon...
# 1     [Giancarlo De Luca, Kim Van Kerckhove, Pietro ...
# 2      [Evans K Lodge, Annakate M Schatz, John M Drake]
# 3     [Ru Liu, Xiaoyan Ming, Ou Xu, Jianli Zhou, Hui...
# 4     [Leon Danon, Ellen Brooks-Pollock, Mick Bailey...
# 5     [Laurent Hébert-Dufresne, Benjamin M Althouse,...
# 6     [Taylor Chin, Caroline O Buckee, Ayesha S Mahmud]
# 7     [Sarah Krieg, Fabian Pott, Laura Eckei, Maud V...
# 8     [Lea Gaucherand, Brittany K Porter, Summer K S...
# 9     [Shenglan Shang, Jiaqi Wu, Xiaoli Li, Xin Liu,...
# 10                  [Nian Shao, Jin Cheng, Wenbin Chen]
# 11    [Ruiyun Li, † , Sen Pei, Bin Chen, Yimeng Song...
# 12    [Huijuan Zhou, Chengbin Xue, Guannan Gao, Laur...
# 13    [Samuel Clifford, Carl A B Pearson, Petra Klep...
# 14    [Richard A Neher, Robert Dyrdak, Valentin Drue...
# 15    [John R Shorter ⇤, Paul L Maurizio, Timothy A ...
# 16    [Zhenyu Li, 1# , Jingwu Ge, Yang 1#, Jianping ...
# 12    the outbreak of the novel coronavirus disease,...
# 13    similar to outbreaks of other respiratory path...
# 14    (2.2 with 90% high density interval 1.4-3.8 (r...
# 15    a critical part of fitness is optimizing the b...
# 16    since december 2019, the outbreak of covid-19 ...
# 17    coronaviruses are single-stranded rna viruses,...
# 18    coronaviruses (cov) (order nidovirales, family...
# 19    the evolution of multicellular eukaryotes from...
# 20    novel coronavirus pneumonia (ncp) is a pathoge...
# 21    intercalating dyes. india. the ten sampling po...
# 22    sars-cov-2 is a recently named novel coronavir...
# 23    in december 2019, a series of pneumonia cases ...
# 24    an epidemic can be described by its speed and ...
# 25    background whether the patients with covid-19 ...
# 26    the clinical and epidemiological characteristi...
# 27    however, in order to fully utilize the potenti...
# 28    individual host heterogeneity in disease sprea...
# 29    covid-19 has been impacting on the whole world...
# ...                                                 ...
# 3821  canine influenza virus (civ) h3n2 is a virus o...
# 3822  t he threat of pandemic infl uenza has generat...
# 3823  r apid differential diagnosis of infectious di...
# 3824  s evere acute respiratory syndrome (sars) is a...
# 3825  d uring the 2014-2016 west africa ebola virus ...
# 3826  a peptide-based enzyme-linked immunosorbent as...
# 3827  a fter the world health organization (who) dec...
# 3828  "lectin" comes from the latin word "legere", w...
# 3829  over the past decade, vietnam has successfully...
# 3830  recently, nosocomial infections have become a ...
# 3831  avian influenza is caused by type a viruses of...
# 3832  . members of the b. burgdorferi s. l. group ar...
# 3833  coronaviruses are large, positive-sense envelo...
# 3834  m iddle east respiratory syndrome coronavirus ...
# 3835  transcription-polymerase chain reaction (rt-pc...
# 3836  a n emerging infectious disease is one that is...
# 3837  our knowledge of the causation of infectious d...
# 3838  d uring the 2003 epidemic of severe acute resp...
# 3839  the farm was a 3-site herd with a total of 6,0...
# 3840  b ovine respiratory disease (brd) is 1 of the ...
# 3841  efforts to contain severe acute respiratory sy...
# 3842  the rapid technological development of medical...
# 3843  m iddle east respiratory syndrome coronavirus ...
# 3844  t he severe acute respiratory syndrome (sars) ...
# 3845  to the editor: bats are now recognized as natu...
# 3846  the seasonal pathogen influenza a virus has th...
# 3847  i n 2005 and 2006 an outbreak of chikungunya f...
# 3848  t he risk that mycobacterium tuberculosis can ...
# 3849  influenza pandemics occur when an animal influ...
# 3850  h uman coronaviruses (hcovs) were first record...
#
#                                       paper_id  \
# 0     013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# 1     02201e4601ab0eb70b6c26480cf2bfeae2625193
# 2     029c1c588047f1d612a219ee15494d2d19ff7439
# 3     0562f70516579d557cd1486000bb7aac5ccec2a1
# 4     05d99c07db59b6948e39bfa62c2cbbf62944059a
# 5     06c1b3535b83251cf92c01258b5048beeab7a460
# 6     090b6c8b3df30bc248221869f673a2d970caa1b9
# 7     09c9fcabc66a106e01ef42247cbd86b6d85bd67f
# 8     09ec8daa8e32168d92d05b86de1784c639685fb4
# 9     0a32446730827ad8152c6a61e4738e4e0b231412
# 10    0cad40f50e41144e8b64744251515eca8cfac5f7
# 11    0eda8331214ca028350b07e2953702f3078a105e
# 12    0fd300aefb704c20f32152b97b6194015f1c74e7
# 13    11f96d05db6854ef95312aa3a4736724ce1f02d6
# 5     beyond r 0 : the importance of contact tracing...
# 6     quantifying the success of measles vaccination...
# 7     mono-adp-ribosylation by artd10 restricts chik...
# 8     the influenza a virus endoribonuclease pa-x us...
# 9     artesunate interacts with vitamin d receptor t...
# 10    the reproductive number r 0 of covid-19 based ...
# 11    substantial undocumented infection facilitates...
# 12    characterizing the transmission and identifyin...
# 13    title: interventions targeting air travellers ...
# 14    potential impact of seasonal forcing on a sars...
# 15    a diallel of the mouse collaborative cross fou...
# 16    original investigation vicarious traumatizatio...
# 17    stochastic discrete epidemic modeling of covid...
# 18    evolution and variation of 2019-novel coronavirus
# 19    glycosyltransferases promote development and p...
# 20    study of the mental health status of medical p...
# 21
# 22    68 consecutive patients assessed for covid-19 ...
# 23    population movement, city closure and spatial ...
# 24       speed and strength of an epidemic intervention
# 25    sars-cov-2 infection does not significantly ca...
# 26    estimating the asymptomatic proportion of 2019...
# 27    establishment of primary transgenic human airw...
# 28    dissecting genetic and sex-specific host heter...
# 29    covid-19 in japan: what could happen in the fu...
# ...                                                 ...
# 3821  inter-and intraspecies transmission of canine ...
# 3822  pandemic infl uenza planning in the united sta...
# 3823
# 3824                                  emergence of sars
# 3825  sustainability of high-level isolation capabil...
# 3826            sars antibody test for serosurveillance
# 3827   remaining questions about clinical variola major
# 3828     lectins: production and practical applications
# 3829  figure. the four regional public health instit...
# 3830  fact-finding survey of nosocomial infection co...
# 3831     ducks: the ''trojan horses'' of h5n1 influenza
# 3832
# 3833  structural basis for human coronavirus attachm...
# 3834
# 3835              early defervescence and sars recovery
# 3836         confl ict and emerging infectious diseases
# 3837  causation and disease: effect of technology on...
# 3838  risk factors for pandemic (h1n1) 2009 virus se...
# 3839  hemagglutinating encephalomyelitis coronavirus...
# 3840  respiratory pathogens in qu ebec dairy calves ...
# 3841
# 3842  european congress of radiology 2012 a postgrad...
# 3843  lack of transmission among close contacts of p...
# 3844  sars-cov infection in a restaurant from palm c...
# 3845
# 3846  microrna-based strategy to mitigate the risk o...
# 3847  chikungunya fever in travelers returning to eu...
# 3848                   nosocomial tuberculosis in india
# 3849
# 3850
#
#                                            sha  \
# 0                                          NaN
# 1                                          NaN
# 2     029c1c588047f1d612a219ee15494d2d19ff7439
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ...                                        ...
# 3821                                       NaN
# 3822                                       NaN
# 3823                                       NaN
# 3824                                       NaN
# 3825  f2d1c4e958f633fefcb90c78a29c8c19bb0562ad
# 3826                                       NaN
# 3827                                       NaN
# 3828                                       NaN
# 3829                                       NaN
# 3830                                       NaN
# 3831                                       NaN
# 3832                                       NaN
# 3833  f6323e7d11e94480fdd62e5caad023d4d2d7cf6d
# 3834                                       NaN
# 3835                                       NaN
# 3836                                       NaN
# 3837                                       NaN
# 3838  f8e19f9d339fc06f51381d54969121f75fcbaf0f
# 3839                                       NaN
# 3840                                       NaN
# 3841                                       NaN
# 3842                                       NaN
# 3843                                       NaN
# 3844                                       NaN
# 3845                                       NaN
# 3846                                       NaN
# 3847                                       NaN
# 3848                                       NaN
# 3849                                       NaN
# 3850                                       NaN
#
#                                                abstract publish_time  \
# 0                                                   nan          NaN
# 1                                                   nan          NaN
# 2     outbreaks emerging infections lack effective d...   2020-01-28
# 3                                                   nan          NaN
# 4                                                   nan          NaN
# 5                                                   nan          NaN
# 6                                                   nan          NaN
# 7                                                   nan          NaN
# 8                                                   nan          NaN
# 9                                                   nan          NaN
# 10                                                  nan          NaN
# 11                                                  nan          NaN
# 12                                                  nan          NaN
# 13                                                  nan          NaN
# 14                                                  nan          NaN
# 15                                                  nan          NaN
# 16                                                  nan          NaN
# 17                                                  nan          NaN
# 18                                                  nan          NaN
# 19                                                  nan          NaN
# 20                                                  nan          NaN
# 21                                                  nan          NaN
# 22                                                  nan          NaN
# 23                                                  nan          NaN
# 24                                                  nan          NaN
# 25                                                  nan          NaN
# 26                                                  nan          NaN
# 27                                                  nan          NaN
# 28                                                  nan          NaN
# 29                                                  nan          NaN
# ...                                                 ...          ...
# 3821                                                nan          NaN
# 3822                                                nan          NaN
# 3823                                                nan          NaN
# 3824                                                nan          NaN
# 3825  identify barriers maintaining applying capabil...     2017 Jun
# 3826                                                nan          NaN
# 3827                                                nan          NaN
# 3828                                                nan          NaN
# 3829                                                nan          NaN
# 3830                                                nan          NaN
# 3831                                                nan          NaN
# 3832                                                nan          NaN
# 3833  coronaviruses cause respiratory tract infectio...   2019 Jun 3
# 3834                                                nan          NaN
# 3835                                                nan          NaN
# 3836                                                nan          NaN
# 3837                                                nan          NaN
# 3838  describe incidence risk factors pandemic hn vi...     2010 Oct
# 3839                                                nan          NaN
# 3840                                                nan          NaN
# 3841                                                nan          NaN
# 3842                                                nan          NaN
# 3843                                                nan          NaN
# 3844                                                nan          NaN
# 3845                                                nan          NaN
# 3846                                                nan          NaN
# 3847                                                nan          NaN
# 3848                                                nan          NaN
# 3849                                                nan          NaN
# 3850                                                nan          NaN
#
#                                               doi
# 0                                             NaN
# 1                                             NaN
# 2               doi.org/10.1101/2020.01.27.921536
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ...                                           ...
# 3821                                          NaN
# 3822                                          NaN
# 3823                                          NaN
# 3824                                          NaN
# 3825     http://dx.doi.org/10.3201/eid2306.170062
# 3826                                          NaN
# 3827                                          NaN
# 3828                                          NaN
# 3829                                          NaN
# 3830                                          NaN
# 3831                                          NaN
# 3832                                          NaN
# 3833  http://dx.doi.org/10.1038/s41594-019-0233-y
# 3834                                          NaN
# 3835                                          NaN
# 3836                                          NaN
# 3837                                          NaN
# 3838     http://dx.doi.org/10.3201/eid1610.100516
# 3839                                          NaN
# 3840                                          NaN
# 3841                                          NaN
# 3842                                          NaN
# 3843                                          NaN
# 3844                                          NaN
# 3845                                          NaN
# 3846                                          NaN
# 3847                                          NaN
# 3848                                          NaN
# 3849                                          NaN
# 3850                                          NaN
#
# [3851 rows x 8 columns]
