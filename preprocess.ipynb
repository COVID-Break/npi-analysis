# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# get raw data from GCP bucket
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

import os
import glob
import json
from datetime import datetime

from google.cloud import storage

# %%
# The bucket name for the location of the data is in the .env file
BUCKET_NAME = os.environ['BUCKET_NAME']
JSON_FILE = 'all_json.pkl'

# %%
class Preprocesser:
    def __init__(self):
        storage_client = storage.Client()
        temp = tempfile.TemporaryFile()
        storage_client.download_blob_to_file(f"gs://{BUCKET_NAME}/{JSON_FILE}", temp)
        self.df_full = pd.read_pickle(temp, compression=None)
        
    def remove_stopwords(self,columns):
        stop = stopwords.words('english')
        for col in columns:
            self.df_full[col] = self.df_full[col].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

    def to_tfidf(self,columns):
        for col in columns:
            tfidfv = TfidfVectorizer()
            self.df_full[col + '_tfidf'] = tfidfv.fit_transform(self.df_full[col])

# %%
prepr = Preprocesser()

# %%
prepr.remove_stopwords(['abstract'])

# %%
prepr.to_tfidf(['abstract'])

# %% [raw]
# prepr.df_full

# %%
prepr.df_full
# Out:
#                                                 abstract  \
# 0      word count: 194 22 text word count: 5168 23 24...
# 1
# 2      infectious bronchitis (ib) causes significant ...
# 3      background: novel coronavirus (2019-ncov) emer...
# 4      faced current large-scale public health emerge...
# 5      viruses interact hundreds thousands proteins m...
# 6      school closure often considered option mitigat...
# 7      post-transcriptional gene silencing (ptgs) pow...
# 8
# 9      human astroviruses small nonenveloped viruses ...
# 10     ribosomal frameshifting translation rna implic...
# 11     recent outbreak infections 2019 novel coronavi...
# 12
# 13     background: outbreaks coronavirus disease 2019...
# 14     outbreak novel coronavirus, named covid-19, fi...
# 15     long-read sequencing technologies invaluable d...
# 16     2019-ncov caused 80 deaths 27 january 2020 chi...
# 17     basic reproductive number -r 0 -is one common ...
# ...
